# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenKP2003/CODTECH-Task1/blob/main/Stocks__Prices__Predtiction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Tesla.csv.csv')

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df.tail()
# Out:
#            Date        Open        High         Low       Close   Volume  \
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998  3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000  7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996  4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988  7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000  6475900
#
#        Adj Close
# 1687  246.169998
# 1688  258.000000
# 1689  255.729996
# 1690  262.049988
# 1691  261.500000

# %%
df.shape
# Out:
# (1692, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.duplicated().sum().any()
# Out:
# False

# %%
df.isnull()
# Out:
#        Date   Open   High    Low  Close  Volume  Adj Close
# 0     False  False  False  False  False   False      False
# 1     False  False  False  False  False   False      False
# 2     False  False  False  False  False   False      False
# 3     False  False  False  False  False   False      False
# 4     False  False  False  False  False   False      False
# ...     ...    ...    ...    ...    ...     ...        ...
# 1687  False  False  False  False  False   False      False
# 1688  False  False  False  False  False   False      False
# 1689  False  False  False  False  False   False      False
# 1690  False  False  False  False  False   False      False
# 1691  False  False  False  False  False   False      False
#
# [1692 rows x 7 columns]

# %%
print(df.corr) # checking the correlation b/w all  column and their relationships
# Out:
# <bound method DataFrame.corr of            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# ...

# %%
# Heat map of all variables(Visulization correlation)
plt.figure(figsize=(16,8))
sns.heatmap(df.drop('Date',axis=1).corr(),cmap='BuPu',annot=True)
plt.show()

# %%
sns.pairplot(df)
#showing visualization on all variables in the data

# %%
df['Open'].hist()
# Out:
# <Axes: >

# %%
df['High'].hist()
# Out:
# <Axes: >

# %%
df['Low'].hist()
# Out:
# <Axes: >

# %%
df['Close'].hist()
# Out:
# <Axes: >

# %%
df['Volume'].hist()
# Out:
# <Axes: >

# %%
df['Adj Close'].hist()
# Out:
# <Axes: >

# %%
# Review the plots
f,axes=plt.subplots(1,5)
sns.boxplot(y='Open',data=df,ax=axes[0])
sns.boxplot(y='High',data=df,ax=axes[1])
sns.boxplot(y='Low',data=df,ax=axes[2])
sns.boxplot(y='Close',data=df,ax=axes[3])
sns.boxplot(y='Adj Close',data=df,ax=axes[4])
plt.tight_layout() # To automatically adjust subplot parameters to give specified padding.

# %%
import plotly.graph_objects as go

figure = go.Figure(data=[go.Candlestick(x=df['Date'],
                                      open=df['Open'],
                                      high=df['High'],
                                      low=df['Low'],
                                      close=df['Close'])])
# Candlestick charts are a technical tool that packs data for multiple time frames into single price bars. This makes them more useful than traditional open, high, low, and close (OHLC) bars or simple lines that connect the dots of closing prices
figure.update_layout(title='Tesla Stock Price Analysis',xaxis_rangeslider_visible=False)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
# splitting the dataset

x=df[['Open','High','Low','Volume']].values #independent variables
y=df['Close'].values #dependent varaible

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#checking the shape for train data
print('Train:',x_train.shape)
print('Test:',x_test.shape)
# Out:
# Train: (1353, 4)
# Test: (339, 4)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score
import statsmodels.api as sm

regressor=LinearRegression()

model=regressor.fit(x_train,y_train)

y_pred=regressor.predict(x_test)

# %%
predicted=regressor.predict(x_test)

# %%
#shape of x_test
predicted.shape
# Out:
# (339,)

# %%
#print the relevant metrics
print("Model Coficients:",regressor.coef_)
#looking at the intercept
print("Model intercept:",regressor.intercept_)
# Out:
# Model Coficients: [-5.71183457e-01  8.54232795e-01  7.16090185e-01 -3.82356172e-08]
# Model intercept: 0.029679013978039848

# %% [markdown]
# ##Prediction Table of Actual Prices Vs Predicted values

# %%
dff=pd.DataFrame(y_test,predicted)
dfr=pd.DataFrame({'Actual_Price':y_test,'Predicted_Price':predicted})
print(dfr)
# Out:
#      Actual_Price  Predicted_Price
# 0       30.090000        31.286019
# 1      258.000000       255.833139
# 2      204.990005       202.604123
# 3       17.459999        16.631611
# 4      263.820007       265.432417
# ..            ...              ...
# 334    183.559998       184.494787
# 335    241.800003       237.835078
# 336    164.220001       167.310263
# 337     29.350000        29.354180
# 338    237.190002       236.669303
#
# [339 rows x 2 columns]

# %%
dfr.describe()
# Out:
#        Actual_Price  Predicted_Price
# count    339.000000       339.000000
# mean     130.033422       130.048430
# std       95.453150        95.473207
# min       15.800000        15.330536
# 25%       29.300000        29.288980
# 50%      148.250000       149.426210
# 75%      219.120002       219.635225
# max      284.119995       282.077847

# %%
residual=y_test-predicted
sns.distplot(residual)
# Out:
# <ipython-input-46-28ded086a1c8>:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: ylabel='Density'>

# %%
import scipy.stats#used for probabilistic distributions and statistical operations
p_value=scipy.stats.norm.sf(abs(1.67))
print('p value is: '+str(p_value))
# Out:
# p value is: 0.04745968180294733

# %%
results2=sm.OLS(y_test,x_test).fit() #Ordinary Least Squares regression (OLS)
results2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          8.370e+05
# Date:                Mon, 29 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        14:06:38   Log-Likelihood:                         -643.01
# No. Observations:                 339   AIC:                                      1294.
# Df Residuals:                     335   BIC:                                      1309.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#checking the regression score
regression_confidence=regressor.score(x_test,y_test)
print("Linear regression confidence:",regression_confidence)
# Out:
# Linear regression confidence: 0.9997086384917272

# %% [markdown]
# ##Model Accuracy

# %%
X=abs(predicted-y_test)
Y=100*(X/y_test)
accuracy=100-np.mean(Y)
print('ACCURACY:',round(accuracy,2),'%.')
# Out:
# ACCURACY: 99.05 %.

# %%
plt.scatter(dfr.Actual_Price,dfr.Predicted_Price,color='Darkblue')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")

plt.show()

# %% [markdown]
# Graphing the first 20 values

# %%
graph=dfr.head(20)
graph.plot(kind='bar')
# Out:
# <Axes: >
